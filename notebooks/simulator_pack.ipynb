# %%
# %matplotlib inline

import numpy as np
from scipy.interpolate import interp1d
import pylab as plt
import ccgpack as ccg

# %%
cl = np.loadtxt('../data/cl_planck_lensed')
sfs = ccg.StochasticFieldSimulator(cl)

# %%
for i in range(5):
    m = sfs.simulate(nside,size)
    np.save('sample_'+str(i),m)

# %%
plt.imshow(m)

# %%
ll,p1 = ccg.power_spectrum(m,size=7.2)

# %%
# plt.plot(Dl,'k--')
plt.plot(ll[:500],p1[:500],'b')
# plt.plot(p2[:1000],'g--')
plt.xscale('log')
plt.yscale('log')
# plt.xlim(1,600)
# plt.ylim(5e-8,5e4)

# %%
import numpy as np

# %%
lst = np.arange(9000,150000,1000)[::10]

ls

# %%
test
# Out:
# array([  9000,  19000,  29000,  39000,  49000,  59000,  69000,  79000,
#         89000,  99000, 109000, 119000, 129000, 139000, 149000])
